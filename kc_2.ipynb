# %%
import pandas as pd
import numpy as np
countries = pd.read_csv("assets/countries.csv")
print(countries.to_string())
# Out:
#    COUNTRY_ID COUNTRY_NAME  REGION_ID
# 0          AR    Argentina          2
# 1          AU    Australia          3
# 2          BE      Belgium          1
# 3          BR       Brazil          2
# 4          CA       Canada          2
# 5          CH  Switzerland          1
# 6          CN        China          3
# 7          DE      Germany          1
# 8          DK      Denmark          1
# 9          EG        Egypt          4
# 10         FR       France          1
# 11         HK     HongKong          3
# 12         IL       Israel          4
# 13         IN        India          3
# 14         IT        Italy          1
# 15         JP        Japan          3
# 16         KW       Kuwait          4
# 17         MX       Mexico          2
# 18         NG      Nigeria          4
# 19          N  Netherlands          1
# 20         SG    Singapore          3
# 21         UK      Kingdom          1
# 22         US      America          2
# 23         ZM       Zambia          4
# 24         ZW     Zimbabwe          4

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
#df=df.astype(float)
#df = df.apply(lambda x : x.astype('int'))
#df = pd.DataFrame({
#    "Name": ["COUNTRY_NAME"],
#    "Region": ["REGION_ID"]
#})

df = pd.DataFrame(countries)
print(df)

#df.dtypes
# Out:
#    COUNTRY_ID COUNTRY_NAME  REGION_ID
# 0          AR    Argentina          2
# 1          AU    Australia          3
# 2          BE      Belgium          1
# 3          BR       Brazil          2
# 4          CA       Canada          2
# 5          CH  Switzerland          1
# 6          CN        China          3
# 7          DE      Germany          1
# 8          DK      Denmark          1
# 9          EG        Egypt          4
# 10         FR       France          1
# 11         HK     HongKong          3
# 12         IL       Israel          4
# 13         IN        India          3
# 14         IT        Italy          1
# 15         JP        Japan          3
# 16         KW       Kuwait          4
# 17         MX       Mexico          2
# 18         NG      Nigeria          4
# 19          N  Netherlands          1
# 20         SG    Singapore          3
# 21         UK      Kingdom          1
# 22         US      America          2
# 23         ZM       Zambia          4
# 24         ZW     Zimbabwe          4

# %%
#bar graph
df.plot(x="REGION_ID", y="COUNTRY_NAME", kind="scatter")
# Out:
# <AxesSubplot: xlabel='REGION_ID', ylabel='COUNTRY_NAME'>

# %%
df.info()
